# %%
import numpy as np
import pandas as pd
from numpy import errstate,isneginf
from sklearn.preprocessing import normalize
import math
import jieba

def search(text):
    file_path = '/home/nlp/Demo/crawler/'
    column_names = ['type','title','text','time','url']
    udn = pd.read_csv(file_path+'udn_demo.tsv',sep = '\t',names=column_names)
    cn= pd.read_csv(file_path+'cn_demo.tsv',sep = '\t',names=column_names)
    ltn= pd.read_csv(file_path+'ltn_demo.tsv',sep = '\t',names=column_names)
    ## concat
    df = pd.concat([udn, cn,ltn], ignore_index=True)
    df = df.dropna()
    type_dict = {}
    ## 0：政治 1：生活 2：國際 3：體育 4：娛樂 5：社會 6：財經
    type_0 = df[df['type'] == '政治']
    type_1 = df[df['type'] == '生活']
    type_2 = df[df['type'] == '國際']
    type_3 = df[df['type'] == '體育']
    type_4 = df[df['type'] == '娛樂']
    type_5 = df[df['type'] == '社會']
    type_6 = df[df['type'] == '財經']
    type_dict['政治'] = 0
    type_dict['生活'] = 1
    type_dict['國際'] = 2
    type_dict['體育'] = 3
    type_dict['娛樂'] = 4
    type_dict['社會'] = 5
    type_dict['財經'] = 6
    test = pd.concat([type_0,type_1,type_2,type_3,type_4,type_5,type_6],ignore_index=True)
    test = test.drop_duplicates(keep='first',subset = 'text', inplace=False)
    ## get text & type
    doc_type = test['type'].tolist()
    doc_title = test['title'].tolist()
    doc = test['text'].tolist()
    ## tfidf
    doc_len_list = [] ##doc len
    all_doc_data = [] ##all doc split
    all_word = {} ##拿來算word_BG的tf值 過濾用
    all_word_idf = {}
    total_word = 0
    ## all doc tf 第一次 建好完整的字典
    for i in range(len(doc)):
        update = {}
        d_content = jieba.cut(doc[i])
        d_content_split = []
        for word in d_content:   ##all word
            d_content_split.append(word)
            if(word in all_word):
                all_word[word] +=1
            else:
                all_word[word] = 1
                all_word_idf[word] = 0
            if word not in update:
                all_word_idf[word] += 1
                update[word] = 1
        all_doc_data.append(d_content_split)
    ##過濾 tf值 得到新的dict
    ##過濾透過長度> 2 不含數字 tf>5 出現在95%以下的文章中
    new_dict = {} ##總共tf>10或是在query裡的字
    # bg_dict = {}
    id2word = {}
    word2id = {} #建完之後對照用的
    id_count = 0
    for word in all_word:
        if(all_word_idf[word]>=10):
            word2id[word] = id_count
            id2word[id_count] = word
            id_count += 1
            new_dict[word] = 0
    Doc = len(doc) ##總共幾篇文章
    Word = len(new_dict) ##總共幾個字
    Query = 1 ##總共幾個query
    R = 5 ##relevant 數量
    NR = 3 ##最爛幾個Non-relevant
    EPOCH = 3 ##Rocchio跑幾次
    tf_idf_matrix = np.load('./numpy_IR/demo_tfidf.npy')
    idf_dict = new_dict.copy()
    for q in range(Query):
        query_content = text
        query_tf = new_dict.copy() ##紀錄tf分數
        update = {}
        query_content = jieba.cut(query_content)
        for word in query_content:
            if word in new_dict:
                query_tf[word] += 1
                if word not in update:
                    idf_dict[word] += 1
                    update[word] = 0
        tf_idf_matrix[q] = np.array(list(query_tf.values()))
    ans_list = []
    ans_index_list = []
    for i in range(Query): ##總共幾個query
        query_ans_list = []   ##排序輸出結果
        score_list = np.matmul(tf_idf_matrix[Query:],tf_idf_matrix[i]) 
        result_score = sorted(range(Doc),reverse = True,key = lambda k :score_list[k])
        for j in range(Doc):
            query_ans_list.append(doc[result_score[j]])
        for k in range(100):
            ans_list.append(query_ans_list[k])
            ans_index_list.append(result_score[k]) ##relevant index
            
    result_list = [] ##分類過後的輸出
    title_list = []
    used_idx = [] ## already output
    used_type =[0,0,0,0,0,0,0]
    for i in range(20):  ##找到七篇就停止
        count = 0
        for check in range(7):
            if used_type[check] != 0:
                count += 1
        if count == 7: ## all type find
            break
        if used_type[type_dict[doc_type[i]]] == 0:
            result_list.append(ans_list[i])
            title_list.append(doc_title[ans_index_list[i]])
            used_type[type_dict[doc_type[i]]] += 1  ## used
            used_idx.append(i) ## used idx
    for i in range(100): ##再找13篇
        if i not in used_idx:
            result_list.append(ans_list[i])
            title_list.append(doc_title[ans_index_list[i]])
        count = len(result_list)
        if count == 20:
            break
    return title_list,result_list

# %%
word = "機師"
title_list,text_list = search(word)
for i in range(20):
    print(i)
    print(title_list[i])
    print(text_list[i])
# Out:
# 0
# 機師薪水比醫學系高卻難考？網曝「入行門檻」一堆人辦不到
# 航空業是大家心中的夢幻職業，每次開放招募總吸引不少人前來求職。對此，有網友表示聽說機師的薪水比醫學系高，因此他不禁好奇「機師到底有多難考」，問題曝光掀起眾人熱議。原PO在PTT發文指出，「看到機師的薪水比醫學系高，但要考試培訓且錄取率極低，到底有多難考，據說現在有非理工科系的或非名校的也考上，有沒有機師鄉民出來說一下開飛機的感想」。貼文一出，網友認為花費高是主要原因，「我只聽說要花幾百萬學」、「先準備個兩百萬去國外學飛，學完後再來考慮有多難考」、「其實不難，但是要花幾年跟300、500萬培訓就一堆人辦不到」、「要讀美國飛行學校，還要考一連串的證照」、「培訓機師報名條件都公開，首先就是英語和體格」、「主要是成本超級高，其他都還好」。
# 1
# 紐籍機師引眾怒綠委開轟：這樣的人不配再來台灣
# 紐籍機師（案765）確診新冠肺炎，廣達集團一名女員工（案771）遭傳染確診，讓台灣253天無本土病例記錄破功。紐籍機師因不遵守防疫原則、不配合疫調，引來各界怒火，民進黨立委林楚茵痛批，「這樣的人不配再來台灣」，要求長榮應對其重罰開除並求償。林楚茵今（23）日在臉書表示，253天零本土案例的努力，因為一位粗野的外籍機師而破功不僅不遵守防疫原則，確診後更不配合疫調，甚至還汙衊醫護、汙衊台灣，對於這樣一位視他人生命安全如無物的禍首，會是一個遵守飛安的好機師嗎？林楚茵認為，該機師所屬的長榮航空應負起台灣企業防疫的表率，對其重罰開除並求償，同時國籍航空也應該一起永不錄用，這樣的人不配再來台灣，建議政府直接列為「不受歡迎人物」，拒絕讓他再次入境。此外，林楚茵昨也PO文提醒民眾做好自身防疫措施，出入公眾場合戴口罩、勤洗手，以平常心面對疫情，並相信衛福部長陳時中與指揮中心同仁的判斷，配合落實防疫。
# 2
# 染疫長榮機師超不配合陳時中：他習慣很不好又隱瞞、我們很生氣
# 衛福部長陳時中今24日接受「周玉蔻嗆新聞」節目專訪。台灣253天武漢肺炎零本土病例因長榮航空染疫紐西蘭籍機師違規而破功，中央流行疫情指揮中心指揮官陳時中對機師相當不滿，指出這機師習慣很不好、且一開始甚麼事情都不講，還認為我們栽贓，我們大家都很生氣。陳時中今天接受電台訪問，講到長榮機師將新冠病毒傳染給其他人的這起案件，說這機師的習慣很不好，是我們非常不認同的，但遭機師感染的女性友人就很守規矩，都有戴口罩。陳時中話鋒一轉，批評機師除了習慣不好外，一開始接受疫調時還甚麼都不講，還不覺得自己有病、只是咳嗽，還認為我們栽贓給他。陳時中越講越生氣，指出大家之所以對長榮機師這麼生氣，是因為機師對疫調不配合，一開始少講一兩個曾去過的地點都還可以理解，「但對於密切接觸者如案771，他怎麼可能不知道或不記得？」陳時中痛批，這機師就是隱瞞，大家不是要找碴，但對於機師不配合疫調，會依照規定開罰，桃園市就開罰了30萬元。「武漢肺炎專區」請點此，更多相關訊息，帶您第一手掌握。
# 3
# 紐西蘭籍機師染疫還趴趴走紐國網友狠批：真是個混蛋
# 長榮航空紐西蘭籍機師感染武漢肺炎導致台灣出現本土感染，這則報導成為紐西蘭電視一台最熱門新聞。長榮航空紐西蘭籍機師感染武漢肺炎一案導致台灣再度出現本土疫情。此事被紐西蘭電視一台詳加報導，也引來紐西蘭網友討論。紐西蘭電視一台《1NEWS》今日以「不誠實！與台灣自4月以來第1起的本土案例有關的紐西蘭機師被罰款1.5萬美元」為標題來報導這起事件。報導稱，一名長榮航空的紐西蘭籍機師由於在接觸史以及旅遊史方面撒謊，因此被罰款了1.5萬美元，這名機師12月初曾入境美國，在當地感染了武漢肺炎，其後又「帶著病毒在台灣北部漫遊」，導致一名30多歲的女性被傳染，並因此終結了台灣8個月無本土案例的紀錄。網友在臉書連結底下留言表示「他們應該罰多一點」、「罰款完再關起來」、「應該罰個5萬美元然後再把他的護照撤銷」，部分網友更狠批「真為他感到羞恥」、「真是個混蛋，讓我們紐西蘭人蒙羞」。「武漢肺炎專區」請點此，更多相關訊息，帶您第一手掌握。
# 4
# 態度變了？染疫紐籍機師爽快繳清30萬元罰款
# 染疫紐籍機師因隱瞞接觸史、妨礙防疫措施介入時機，遭桃園市衛生局重罰新台幣30萬元，限期31日前要繳清。桃園市衛生局今天表示，機師已透過友人協助，在昨天傍晚繳清罰款。衛生局表示，紐西蘭籍機師（案765）在機上工作時咳嗽未戴口罩，還在可傳染期在台趴趴走，傳染給女性友人（案771）。機師事後遭長榮航空開除，交通部也開罰長榮航空100萬元。衛生局表示，機師於疫調時未詳實告知接觸及活動史，防礙防疫措施介入時機，造成傳染他人及社區感染風險，依傳染病防治法第67條第1項第3款加重處罰30萬元。衛生局表示，處分書在24日正式開出並由承辦人員直接送到醫院病房，由醫護人員轉交給機師簽收，衛生局人員也透過病房電話向機師說明；依照規定，機師需在7天內繳清罰款，也就是最後繳款日為31日，若未期限內完成繳款，就會移送行政執行署強制執行。衛生局今天表示，機師透過友人協助，昨天上午以線上匯款方式繳納，但因不明操作原因繳納失敗，衛生局也沒有收到罰款，下午再度嘗試後繳款成功，衛生局也在昨天傍晚確認罰款金額入帳。（編輯：李錫璋）1091230
# 5
# 副機師約砲對話外洩！1次不超過3小時抓姦過程曝光
# 與確診紐籍機師同屬777機隊的一名副機師，隱瞞已婚身分，在隔離期間約砲多名女生，無視防疫規定，長榮航空前天也火速開除該名副機師。對此，資深機師詹姆士在節目上爆料，認識其中一位受害女子，且部分受害者還組成渣男受騙協會，導致整件事情曝光。資深機師詹姆士在談話節目《前進新台灣》上爆料，認識被已婚長榮副機師騙財騙色的女子，該女表示，兩人交往三年左右，但女方一直不知道對方已婚。直到某天渣男機師醉倒，放在玄關上的手機不斷收到訊息，受害女好奇拿起來看，才發現驚人真相。詹姆士表示，受害女子發現副機師的Line裡滿滿都是約砲對話，讓她看了怒火滔天，直接群發訊息給渣男的砲友們，表明自己是正牌女友，且「渣男機師現在就睡在旁邊，若還相信他單身，那就跟我一樣笨，我已是受害者，如果你們不信就加我LINE。」從對話截圖中可見，一名女子提到，每次和這名副機師見面都不超過三個小時，不知道對方在趕什麼，如今也真相大白。不過，由於受害女發訊息的時間為凌晨，僅少數人已讀，而唯一回電給受害女的，竟是副機師的妻子，也才讓渣男已婚的身分曝光。詹姆士也說，該名副機師直到被受害女叫醒，才知事情大條了！他當下立刻拿手機，衝到廁所裡面收回訊息，因此最後只有5、6個人看到受害女所傳送的訊息。不過，已看見訊息的幾名受害女子，最後也決定組織渣男受騙協會。詹姆士指出，其中有一名女子不甘心受害，摸清渣男的班表後，便偷偷在對方家中的停車場蹲點等他，發現該名副機師死性不改，在居家檢疫期間繼續約砲，讓她氣得將此事公諸於眾，整件事情才曝光。
# 6
# 外籍機師薪水有多高？關鍵門檻曝光眾人驚呆
# 紐西蘭籍機師（案765）確診後仍到處趴趴走，又傳染給廣達集團女員工，打破台灣253天無本土病例紀錄。新聞引起熱議後，機師行業也引發外界好奇，考上機師有多難？薪水究竟有多高？網友透露，機師薪水比醫學系畢業的還高，不過要付出的「成本」也超級高，關鍵門檻曝光後讓眾人驚呆，認為飯碗恐怕比台積電還難捧。根據資料顯示，華航機師年薪300萬至500萬元，長榮機師年薪約450萬至700萬元，至於外籍航空機師薪水則在500萬至700萬元之間，薪水高到讓上班族無法想像，加上近來機師引起廣大討論，因此有網友好奇在PTT上詢問「考上機師有多難？」問題一出馬上引發熱議。原PO在PTT發文表示，看到機師薪水比醫學系畢業的還高，但聽說要考上培訓機師的錄取率很低，想知道到底有多難考？不少網友回應，「首先就是英語和體格」、「體檢就先刷掉一大半了」、「體檢、英文、學習能力都很吃重，這飯碗比台積電還難捧」。還有內行網友點出一個關鍵門檻，可瞬間刷掉一堆人，就是「成本」超級高，因為要到國外讀飛行學校，還要考一連串的證照，幾年花個3、5百萬，光是培訓就有一堆人辦不到；此外，也有人說考上機師後一個月幾乎有半個月都不在家，對身體狀況也要求很高，一不小心就不能飛了，並不是任何人都能勝任，規定相當嚴格。關鍵門檻曝光後讓眾人驚呆，網友紛紛回應「上機師比較簡單，考上就不用想了」、「你去考就知道」、「學費比較難」、「先搭上鐵達尼號」、「先準備個兩百萬去國外學飛，學完後再來考慮有多難考」。
# 7
# 紐籍機師違規釀群聚機組員檢疫規定朝2方向研議
# 紐西蘭籍機師違反防疫規定釀多人染疫，指揮中心今天將和相關單位開會研議加嚴防疫措施，衛福部次長石崇良今天表示，將從加強採檢及延長檢疫時間等2方向研議。長榮航空一名紐西蘭籍機師確診武漢肺炎（2019冠狀病毒疾病，COVID-19），早已出現咳嗽症狀卻不戴口罩，甚至在自主健康管理期間違規進出百貨公司、大賣場等公共場所，疫調也不誠實，不僅屢次違反防疫規定，甚至造成2名同事及1名友人感染，也讓台灣零本土案例紀錄在253天止步。此案例一出，引發外界對機組人員檢疫規定的質疑，民進黨立委莊競程今天在立法院質詢石崇良時指出，目前機組人員的檢疫規定中，機師為3天、空服組員為5天，紐西蘭機師的案例顯示機組人員會走入社區，這樣的檢疫規定是否要再做檢討。石崇良回應，過去的確考慮機組人員的工作特性而有例外規定，但針對紐西蘭機師的案例，指揮中心上午11時將開會研議加嚴防疫措施，預計朝2方向研議，包含：加強採檢並要求人員入社區之前必須先採檢，以及延長檢疫時間，不再是只有3天或5天，預計在下午記者會宣布討論結論。（編輯：張雅淨）1091223
# 8
# 紐籍機師「極樂台北」陳時中怒：兩人每天膩在一起
# 紐籍機師接受疫調時，不僅隱瞞活動史、接觸史，入住負壓隔離病房也相當不配合，對此，指揮官陳時中今接受廣播節目專訪時動怒，說忘記一兩處吃飯地還情有可原，但天天與廣達集團女員工在一起卻說忘記，才令人生氣。陳時中今接受廣播節目《周玉蔻嗆新聞》中指出，紐籍機師（案765）接受疫調人員調查時，問及活動史時，他一概以「忘記了、不清楚」作答，陳時中憤怒地表示，若是忘記一兩處吃飯地，還情有可原，但天天與廣達集團女員工（案771）膩在一起，「這怎麼可能會忘記」。陳時中也表示，於自主健康管理期間是被放寬的，他（紐籍機師）應要更檢點自己的生活，但他去的地方實在太多了，自主健康管理應是將口罩戴好，避免出入人多擁擠空間。陳時中進一步指出，紐籍機師與廣達集團女員工出遊，兩人相比，廣達集團女員工口罩戴得比較好，紐籍機師因進入百貨公司都未佩戴口罩，才會將百貨公司等足跡列為公布地。陳時中透露，紐籍機師從確診至入住負壓隔離病房，態度一直都非常不好，直至前一日仍認為自己沒有病，昨日狀況才比較穩定，陳時中無奈說道「他們對於新冠肺炎的警覺性及了解程度，實在太低了」。
# 9
# 紐籍機師違反防疫規定民航局：長榮查清楚會開除
# 新冠肺炎本土案例第253天零確診破功，因為長榮紐西蘭籍機師隱瞞接觸史及活動史，傳染給有密切關係的廣達集團女員工，引發相當大民怨，衛福部又指出該名機師在飛機上沒戴口罩還一直咳嗽。民進黨立委林俊憲今天在立院質詢此事，民航局長林國顯表示，長榮航空告訴他，此事會先查清楚，查清楚就會開除他。林俊憲質疑，機師的防疫措施跟旅客不同，只需要隔離三天，是因應航空公司人力需求給予他們特別的措施，當初讓他們可以這樣就是因為他們必須做好自主管理，結果這次卻發現這名機長在機上一直咳嗽還不戴口罩。林俊憲進一步指出，這次衛福部說不能開罰他不戴口罩，理由是必須要「經勸導」才能罰，但因為他是機長所以沒人可以勸他，「是有什麼黑暗面？」但林國顯說，旁邊的機師「有勸他、有提出來」，疫調跟說明可能不太一樣。林俊憲也提到，長榮航空日前有三名空姐違反居家檢疫規定，遭到航空公司開除，現在這個機長違反規定是不是也會開除？還是只敢拿空姐開刀不敢拿機師開刀？林國顯說，長榮航空是告訴他，先調查清楚，調查清楚之後再開除。
# 10
# 機師只需隔離3日就能趴趴走網開酸：防疫最大笑話
# 紐籍機師（案765）確診新冠肺炎，害機上2名同事染疫，還與一名廣達30多歲女員工（案771）密切往來，打破台灣253日無本土病例，造成民眾恐慌。而機師居家檢疫只需3日，引發網友不滿大罵「根本是防疫漏洞」，堪稱是防疫笑話。該名網友今（23）日於PTT八卦板發文指出，一般老百姓不管去的國家是不是疫情重災區，舉凡歸國就要隔離14日，隔離期間若離開房門買泡麵，則會被處10萬罰鍰，但機師竟然只隔離檢疫3日，令原PO相當傻眼。原PO表示，機師往返多個國家，染疫風險本就高於一般民眾，原PO認為政府為防疫，表面說得冠冕堂皇，私下卻又不斷地為特定人士開特例，痛批「全民防疫根本是個笑話，叫那些被罰鍰的民眾情何以堪？」據指揮中心規定指出，機師入境後需居家檢疫3日；客艙組員及機務人員需居家檢疫5日，即可解禁。此規定本是方便飛航人員停頓後再飛，可緩解航空作業順利、人手不足問題，本是一番美意，但卻有不少民眾質疑。貼文曝光後，一票網友都表示認同，直言「所以依照政府的邏輯，人手不夠的企業都可以比照辦理？」其中一名網友也認為「3天結束檢疫沒什麼問題，問題是到處趴趴走，且防護也要做齊，若以上都沒做到都要重新檢討了」。
# 11
# 紐籍機師收30萬罰單桃園衛生局：限7天內繳清
# 紐西蘭籍機師（案765）趴趴走，害廣明光電子公司女員工染疫，打破台灣253天無本土病例紀錄。該機師因不配合疫調，桃園市衛生局重罰30萬元，24日平安夜由衛生局人員親送到醫院，交醫護人員轉交，若7天內沒繳清罰單，就送行政執行署強制執行。桃園市衛生局表示，處分書原本採郵寄雙掛號寄到通訊地址，但考量機師還在隔離病房，因此由衛生局人員送到醫院，請醫護人員轉交，若7天內他未繳清30萬元，就會請行政執行署強制執行。行政執行署桃園分署表示，若收到案件，且個案沒有財產可強制執行，根據《行政執行法》第17條，有必要將限制出境。紐籍機師因不配合疫調，更在飛機上不戴口罩，長榮航空23日透過電話連線方式召開紀律委員會，一致決議做出免職處分。
# 12
# 確診機師被爆曾赴日本交流協會網驚：顧立雄、王美花隔天也去
# 一名來自紐西蘭的機師，攻破台灣引以為傲的「本土防線」。而台北市議員徐巧芯今(23)日在臉書上公開該染疫機師本月9日在台北的活動路徑，並指出他在當天有出現在「日本交流協會」。而因國安會秘書長顧立雄與其妻子經濟部長王美花，10日也曾秘密前往該交流協會，這個巧合讓網友直呼，難道我國內閣成員也出現染疫危機？徐巧芯今日在臉書中爆料，指出中央疫情指揮中心沒有公開案765在9日的活動紀錄，表示該機師在當天曾前往「日本交流協會」以及松山區等其他地方，而這個消息也讓當地居民相當擔憂，呼籲指揮中心應該要秉持公開、透明，讓民眾知道他們該知道的訊息。而有網友指出，本月初10日晚間，顧立雄以及王美花在仰德大道被爆發生「車禍」，因此曝光當日兩人曾前往位於陽明山的日本交流協會，後來王美花認了有去過日本交流協會，但表示車禍與他們無關。不過，在傳出確診機師在12月9日也曾去過日本交流協會後，有人也想到顧立雄、王美人花10日也去了日本交流協會，因而有點擔心兩位政要的健康情形。網友直呼「這也太巧了吧」、「都過快半個月了，會不會已經傳開了？」「內閣淪陷？」「慘了，超大破口」、「難道就是因為這樣所以才沒有公開嗎？」
# 13
# 柯酸陳時中壓力很大機組員檢疫應14天
# 紐籍機師違反防疫規定釀本土病例，因此未來機組員入境後擬居家檢疫7天且採檢陰性，才可進入社區。對此，台北市長柯文哲認為，應比照一般旅客居家檢疫14天，並設置專區或園區坐隔開，並諷衛福部長陳時中壓力很大。柯文哲表示，若是他的做法，一般旅客居家檢疫14天，乾脆機師也應比照14天的標準，並且自主管理7天，只是要給這些機師或空服人員，設置專區或園區，和一般社會也要做隔開。柯文哲認為，因為中央政府那些感染專家很多都是我以前台大同事，所以他們只要認為還可行，我們都想辦法配合，不過之前機師3至5天，以我專業立場來看，那是破口。至於陳時中指柯「自己說謊」，柯文哲表示，這是媒體傳話，他不會在意什麼說謊不說謊。柯強調，主張全部公開，若陳時中說可以控制就不公開，不能控制就公開，但質疑控制與不控制是用哪一套標準來決定，所以應公布一套規則，並解釋規則如何訂定。柯文哲指出，針對紐籍機師足跡，連我們這些專家都嚇一跳，很怕突破防疫網，若到社區感染更是不得了，陳時中當時壓力應該也很大，所以陳時中的說法，他不在意，有時候媒體傳話的時候會讓人誤會。此外，針對英國班機回來有人發燒，柯文哲說，如果真的是發燒，把他攔下來就好，看他的登機前檢查紀錄，而且從英國到台灣飛機，飛行時間10幾個小，若真的是發燒上飛機那慘了，全飛機這麼多人要怎麼處理？
# 14
# 紐籍機師隱瞞疫調、被爆辱醫護林楚茵氣炸臉書開飆
# 民進黨立委林楚茵在臉書痛批不配合疫調的紐籍機師「視他人生命安全如無物的禍首」，建議長榮航空應對他「重罰開除並求償」之外，國籍航空也該對他「永不錄用」。資料照。國內昨出現1例武漢肺炎本土病例，終結253天零確診紀錄。確診女子是先前案765的紐西蘭籍機師的接觸者，由於這名紐籍機師確診後拒不配合疫調工作，甚至疑似在隔離病房對醫護人員惡言相向，惹怒台灣民眾。民進黨立委林楚茵也開飆，「視他人生命安全如無物的禍首」，建議長榮航空應對他「重罰開除並求償」之外，國籍航空也該對他「永不錄用」，政府直接列為「不受歡迎人物」。案765的紐籍機師在機上執勤時，就出現症狀狂咳，卻不配戴口罩，傳染給另外2名同事，釀成機上群聚感染，在接受疫調時，謊稱「想不起來」，未誠實透露案771本土病例接觸史，導致防疫破口長達10天，甚至在22日有網友上PTT爆料，稱染疫機師入住負壓病房時態度囂張，大發脾氣，拒絕配合醫師和護理師，他自認沒染疫，稱台灣人惡意中傷，用假的檢驗報告，硬把他抓進醫院。對此，立委林楚茵今日在臉書氣憤指出，這名外籍機師不僅不遵守防疫原則，確診後更不配合疫調，甚至還汙衊醫護及台灣，如此「視他人生命安全如無物的禍首，會是一個遵守飛安的好機師嗎？」，要求長榮航空應做台灣企業防疫的表率，「對其重罰開除並求償」，國籍航空也該對他「永不錄用」，甚至建議政府直接列為「不受歡迎人物」，重話批「這樣的人不配再來台灣」。「武漢肺炎專區」請點此，更多相關訊息，帶您第一手掌握。
# 15
# 長榮女機師確診發病前14天多在台
# 女機師旅遊接觸史中央流行疫情指揮中心昨公布新增兩例武漢肺炎境外移入病例，都是自美國返台後確診，其中一名是長榮航空女機師，她在發病前十四天多數時間待在台灣，不能排除本土感染疑慮，但指揮中心認為機率相當低。這名卅多歲女機師本月十二日飛往美國，十六日返台後前往公司宿舍居家檢疫，同天出現咳嗽、流鼻水、全身痠痛、發燒等症狀，就醫後採檢確診，Ct值高達十七，代表病毒量高、剛感染狀態。指揮中心發言人莊人祥說，病例發病前十四天多數時間待在台灣，當中也有飛到其它國家，相關旅遊史都可能是感染源、不能排除是在台灣感染、但機率最低。與案七六○同行前往美國的九位同事中，一人在航程途中有咳嗽症狀，且未配戴口罩，其餘同行者皆有配戴口罩，已進一步採檢及疫調。針對女機師染疫一事，長榮航空並未否認，僅表示一切尊重指揮中心說法。莊人祥說，女機師在十七日檢測當天病毒量很高，推測感染源有三種可能，包括發病前在台灣、到美國的航程和美國當地，若在航程中被同事感染，那十二日感染、十六日發病，四天的潛伏期很常見。這並非首例國籍航空機師確診武漢肺炎，三月底也有華航二名貨機機師確診，但首次有女性機師確診。
# 16
# 紐籍機師、廣達妹趴趴走何時落幕醫：1／29是關鍵
# 紐籍機師確診新冠肺炎，還將病毒傳染給2名同事、1名廣達集團女員工，兒童感染科醫師謝宗學表示，紐西蘭機師12月8到11日在北部趴趴走、進入社區，至少要28天無本土病例事情才能落幕，但全案強碰耶誕、跨年、元旦群聚，要真正安全至少要到明年1月29日之後。紐籍機師與廣達女員工12月7到12日密切接觸，且於8至11日間進入社區，逛北巿天母百貨、桃園美式賣場，使廣達女員工染上病毒，12月14日出現咳嗽、鼻塞症狀，但直到21日才被警政單位找到採檢確診，由於出現症狀前二天就具有傳染力，所以廣達妹等於在具傳染力期間已進入社區10天，造成全民恐慌。中山醫學大學附設醫院兒童急診科主任醫師謝宗學表示，紐籍機師趴趴走後從12日算起，要經過2個14天的循環，也就是連續28天無本土病例，這次的事件才能落幕，然而這28天裡將經歷耶誕節、跨年和元旦群聚活動，所以真正安全的時間將是元旦後的28天後，也就是1月29日以後。謝宗學表示，現在只能禱告因紐籍機師和廣達妹被匡列的接觸者256人都沒有被感染，事情才能儘快結束，但他個人覺得事情並不樂觀，因為正值冬天，台灣人防疫一般已經鬆懈很久，沒有防疫基礎，台灣的奇特經濟榮景將不復存在，「今天的本土病例確診、股市長黑，或許是一切反轉的開始，若大家還是沒有嚴肅正視防疫習慣，現在世界上許多國家的慘況就是台灣未來的風景。」
# 17
# 機師圈再爆案765離譜黑歷史網一看氣炸
# 國內連續253天零本土確診破功！中央流行疫情指揮中心昨（22）日公布新增1例本土病例（案771）為廣達集團女員工，其感染源就是(案765)紐西蘭外籍機師，且這名機師僅居家檢疫三天就進入社區趴趴走，消息曝光後，機師被瘋狂起底，現在機師圈又爆料，傳出他早在巴黎外站時就不守規矩，到處趴趴走。陽明醫學博士胸腔重症醫師蘇一峰昨晚在臉書發文表示，機師圈再爆出這名紐西蘭籍的機師，早在先前飛巴黎外站時就已不守規，外出趴趴走，但公司卻未直接開除；甚至染疫之後，面對疫情指揮中心疫調也非常不配合，故意不說出和他密切往來的女性友人行蹤，導致台灣再現本土案例。蘇一峰指出，案765除了面對疫調非常不配合外，更傳出他入住負壓病房時態度非常不配合、一直發脾氣，常咄咄逼人問問題，也不願意配合醫師、護理師。據傳案765認為檢驗報告是假的，是台灣人要害他，只是因為同事被感染，台灣政府就急著要找代罪羔羊，根據同事的片面之辭就判定他有生病。甚至一直到昨天早上，案765都認為自己沒有生病，是台灣人惡意中傷他，硬要把他抓進醫院。消息曝光後引起全民公憤，網友氣炸，紛紛留言「照顧這瘋子真是浪費醫療資源，叫他快滾」、「直接火化吧，不要浪費我們的健保」、「案765不但沒有責任感、沒有道德觀，還人在福中不知福」、「真的很可惡」、「這樣態度，為什麼不趕他出境，以後都禁止他來台灣」。長榮航空已回應，全面配合中央流行疫情指揮中心疫調，消毒公司、航機，對於機師違規、妨礙疫調，將召開事實調查委員會及紀律委員會，若違規屬實將予以免職處分。
# 18
# 罵陳時中舔美賣台網友遭北檢起訴
# ◎罵陳時中舔美賣台網友遭北檢起訴賴姓男子因不滿衛福部長陳時中對新冠肺炎的防疫政策，今年6月在臉書粉絲頁，PO文「阿中部長隱暪疫情，無恥舔美賣台」，陳時中發現後，憤而提告。台北地檢署今依公然侮辱罪起訴賴男。◎民團舉行「文化抵抗記者會」反萊豬邀市民凱道跨年無國界人權觀察團、民間反瘦肉精毒豬聯盟上午在群賢樓大門口舉行文化抵抗記者會，邀請市民跨年作伙，在31日到元旦，在凱道前另類跨年，宣示自己寧做街頭的主人，不做美國的奴隸；寧願餐風飲露，不吃民進黨的毒豬！◎再爆機師亂防疫長榮副機師居檢期約砲遭免職繼紐籍機師在機艙內拒戴口罩，染疫後又不配合疫調，並導致2同事1友人全中鏢，遭長榮航空開除後，今天又爆出長榮副機師在居檢期間約炮，視防疫規定為無物，長榮航空表示，昨已該開除該名副機師，截至目前已有4名空服員、4名機師因違反防疫規定，遭到公司免職。◎杜蘭特厄文缺陣籃網延長不敵灰熊吞2連敗季前被視為奪冠熱門球隊的籃網，沒想到杜蘭特與厄文兩大主將今日同時缺陣，加上丁維迪也受傷，導致與灰熊之戰戰力短缺，最終在經過延長賽苦戰後111比116飲恨敗北，吞下2連敗。
# 19
# 紐西蘭籍機師事件管理學者提醒小心陷入這種陷阱
# 長榮航空紐西蘭籍機師感染新冠肺炎又違反防疫規定，造成3人染疫，台灣本土253天零確診紀錄也因此破功。大學管理學者也從管理學層面提出看法，認為這是典型的「機長症候群」(Captainitis)也就是在職場與人際互動中，充滿了「服從權威」(ObediencetoAuthority)的現象，這卻可能因這樣的現象而造成錯誤發生，而不能及時扭轉。大學助理教授洪堯棟指出，學者們探討航空公司墜機的原因，發現往往跟「文化因素」有關，也就是重視尊卑地位關係的機長與副機長，在發生重大的危機時，機長作出錯誤判斷時，副機長受制於權威關係，沒能以明確堅定的語言說出自己的建議，呼籲機長修正錯誤。日本福島核污染事件調查委員會主席東京大學黑川清教授在報告摘要中表示，根本原因在於日本根深蒂固的文化，「我們反射性的服從、不願意質疑當權者與權威」。他說，社會上有許多服從權威的案例，例如法官、醫師因地位崇高，許多人不敢質疑他們的意見，也有歹徒利用這種心理進行詐騙，像是有人假冒警察或是檢察官詐騙等。洪堯棟說，企業要避免陷入服從權威這樣的陷阱，就要鼓勵創新的企業文化，例如在企業裡勇敢發言，而不是因官大學問大，只以老闆的意見為意見，造成錯誤的判斷和後果。企業要鼓勵員工勇於發言、提出意見，也應創造有利的環境、塑造創新的企業文化，例如鼓勵員勇於發言之外，也該製定出規則，保障員工的權益，讓員工不因發言而受到懲罰。而員工要保障自己權益，也可進行相關的書面紀錄，像是副機師若已提醒機師應戴口罩，機師卻不聽，副機師可以就相關事項記錄，以利事後查證，保護自己。
